# %% [markdown]
# # testing models from CMIP6 historical runs
# This script opens up CMIP6 historical model run files with data on precipitation pr and surface temperature tas and calculates monthly anomalies for each region.  Then tests the models for each region.

# %%
import xarray as xr, matplotlib.pyplot as plt
#import sys 
#sys.path.append('/home/563/kb6999/Models') # use this if the function file is in a different directory to the notebook
from importlib import reload # need to use this if I edit a function file
import os
import numpy as np
import pandas as pd
import cartopy.crs as ccrs # to add in continents and change map projections 
from matplotlib.colors import LinearSegmentedColormap # to change colour bar????
import dask.diagnostics # dask allows you to check how long something is taking to load

# %%
# import custom functions
import anomaly_function as func # imports the function
import model_figures as func2

# %%
# use this to reload the function file if I make any edits to it
func = reload(func) 
func2 = reload(func2)

# %%
# !ls /g/data/lp01/CMIP6/CMIP/CAS/CAS-ESM2-0/historical/r1i1p1f1/Amon/pr/gr1.5
# Out:
# v20200302

# %%
# store each section of the directory as a string
institution_dir = '/g/data/lp01/CMIP6/CMIP/'
tas_dir = '/historical/r1i1p1f1/Amon/tas/gr1.5/'
pr_dir = '/historical/r1i1p1f1/Amon/pr/gr1.5/'
print(institution_dir, tas_dir, pr_dir)
# Out:
# /g/data/lp01/CMIP6/CMIP/ /historical/r1i1p1f1/Amon/tas/gr1.5/ /historical/r1i1p1f1/Amon/pr/gr1.5/

# %% [markdown]
# ## Read in model data

# %%
models_tas = func.read_models(institution_dir, tas_dir, '1850-01','2015-01')
# Out:
# 49 model paths found and loaded into the dictionary "models"
# Path for MCM-UA-1-0 does not exist
# Model MPI-ESM1-2-HR has different time so is now removed
# Model E3SM-1-0 has different time so is now removed
# Model EC-Earth3-Veg has different time so is now removed
# 45 models have been successfully loaded into an xarray

# %%
models_pr = func.read_models(institution_dir, pr_dir, '1850-01','2015-01')
# Out:
# 48 model paths found and loaded into the dictionary "models"
# Path for MCM-UA-1-0 does not exist
# 47 models have been successfully loaded into an xarray

# %%
# make sure the models are the same for both vairables
# delete the height from the models_tas array (if it hasn't been deleted already)
if 'height' in models_tas:
    del models_tas['height']
# delete models that aren't common between variables
models_tas = models_tas.where(models_tas.model.isin(models_pr.model), drop = True)
models_pr = models_pr.where(models_pr.model.isin(models_tas.model), drop = True)
#chekc that the models are the same for both variables and if so print True
models_tas.model.equals(models_pr.model)
# Out:
# True

# %%
# combine precipitation and temperature into one dataset
models = xr.Dataset({'tas': models_tas.tas, 'pr': models_pr.pr})
# change the pr units
models['pr'] = models.pr*86400
models
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 120, lon: 240, model: 44, time: 1980)
# Coordinates:
#   * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#   * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#   * time     (time) datetime64[ns] 1850-01-31 1850-02-28 ... 2014-12-31
#   * model    (model) <U17 'MPI-ESM-1-2-HAM' 'NESM3' ... 'SAM0-UNICON' 'IITM-ESM'
# Data variables:
#     tas      (model, time, lat, lon) float32 dask.array<chunksize=(1, 12, 120, 240), meta=np.ndarray>
#     pr       (model, time, lat, lon) float64 dask.array<chunksize=(1, 12, 120, 240), meta=np.ndarray>

# %%
# get rid of models with issues
models = models.drop_sel(model=['CIESM'])

# %%
# sort models alphabetically and prints final model list
models = models.sortby('model')
print('The following', len(models.model.data), 'models will be used in all subsequent calculations: \n')
print(models.model.data)
# Out:
# The following 43 models will be used in all subsequent calculations:
#
# ['ACCESS-CM2' 'ACCESS-ESM1-5' 'AWI-CM-1-1-MR' 'AWI-ESM-1-1-LR'
#  'BCC-CSM2-MR' 'BCC-ESM1' 'CAMS-CSM1-0' 'CAS-ESM2-0' 'CESM2' 'CESM2-FV2'
#  'CESM2-WACCM' 'CESM2-WACCM-FV2' 'CMCC-CM2-HR4' 'CMCC-CM2-SR5' 'CanESM5'
#  'E3SM-1-1' 'E3SM-1-1-ECA' 'EC-Earth3' 'EC-Earth3-AerChem'
#  'EC-Earth3-Veg-LR' 'FGOALS-f3-L' 'FGOALS-g3' 'FIO-ESM-2-0' 'GFDL-CM4'
#  'GFDL-ESM4' 'GISS-E2-1-G' 'GISS-E2-1-G-CC' 'GISS-E2-1-H' 'IITM-ESM'
#  'INM-CM4-8' 'INM-CM5-0' 'IPSL-CM6A-LR' 'KACE-1-0-G' 'MIROC6'
#  'MPI-ESM-1-2-HAM' 'MPI-ESM1-2-LR' 'MRI-ESM2-0' 'NESM3' 'NorCPM1'
#  'NorESM2-LM' 'NorESM2-MM' 'SAM0-UNICON' 'TaiESM1']

# %% [markdown]
# ## select out time around krakatoa eruption
# I need to select out the time around each eruption or at least store each eruption in a separate array so that I don't get a "minimum" for one eruption in 1891 and the next in 1991

# %%
# select out time around krakatoa eruption
models = models.sel(time = slice('1850-01','1900-01'))
models
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 120, lon: 240, model: 43, time: 601)
# Coordinates:
#   * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#   * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#   * time     (time) datetime64[ns] 1850-01-31 1850-02-28 ... 1900-01-31
#   * model    (model) <U17 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'TaiESM1'
# Data variables:
#     tas      (model, time, lat, lon) float32 dask.array<chunksize=(1, 12, 120, 240), meta=np.ndarray>
#     pr       (model, time, lat, lon) float64 dask.array<chunksize=(1, 12, 120, 240), meta=np.ndarray>

# %%
# eruption date
e_date = pd.to_datetime(['1883-08','1902-10', '1963-03', '1982-04', '1991-06'])

# %%
# save arrays of times relative to each eruption
e_pre5yrs = e_date - 60 * pd.offsets.MonthBegin()
e_pre3mon = e_date - 3 * pd.offsets.MonthBegin()
e_post6mon = e_date + 7 * pd.offsets.MonthBegin()
e_post12mon = e_date + 13 * pd.offsets.MonthBegin()
e_post18mon = e_date + 19 * pd.offsets.MonthBegin()
e_post24mon = e_date + 25 * pd.offsets.MonthBegin()
e_post5yrs = e_date + 61 * pd.offsets.MonthBegin()
e_post10yrs = e_date + 121 * pd.offsets.MonthBegin()

# %% [markdown]
# ## Select out regions
# Right now I have all the models stored in one array so from hereafter I can calculate anomalies etc.

# %%
# area weighting 
models_w = models*np.cos(models_tas.lat*(np.pi/180))

# %%
# import land fraction data
landfrac_ds = xr.open_dataset('/home/563/kb6999/Models/landfraction_file_grid1.5.nc')
landmask = landfrac_ds.mean(dim='time')

# %% [markdown]
# ## Anomalies

# %%
# use functions to calculate the monthly anomalies for the globe
mon_anom_Glob = func.monthly_anomaly(models_w, '1850-01', '1881-01')

# %%
# select out regions for other anomalies 
mon_anom_SH = mon_anom_Glob.sel(lat=slice(-90,0)) 
mon_anom_NH = mon_anom_Glob.sel(lat=slice(0,90)) 
mon_anom_Aus = mon_anom_Glob.sel(lat=slice(-50,-10), lon=slice(110,160)).where(landmask.data==1, drop=True)
mon_anom_EA = mon_anom_Glob.sel(lat=slice(-50,-10), lon=slice(140,155)).where(landmask.data==1, drop=True)

# %%
# use function to add in the mmm to the array, labelled as 'Multi-model mean' in the model dimension
multi_model_Glob = func.add_mmm(mon_anom_Glob)
multi_model_SH = func.add_mmm(mon_anom_SH)
multi_model_Aus = func.add_mmm(mon_anom_Aus)
multi_model_EA = func.add_mmm(mon_anom_EA)

# %%
# take the lat lon mean before taking the std 
mean_mon_Glob = multi_model_Glob.mean(dim = ['lat','lon'])
mean_mon_SH = multi_model_SH.mean(dim = ['lat','lon'])
mean_mon_Aus = multi_model_Aus.mean(dim = ['lat','lon'])
mean_mon_EA = multi_model_EA.mean(dim = ['lat','lon'])

# %%
# calculate the standard deviation for each model over the time period from 1850-1880
std_Glob = mean_mon_Glob.sel(time = slice('1850-01', '1881-01')).std(dim = ['time'])
std_SH = mean_mon_SH.sel(time = slice('1850-01', '1881-01')).std(dim = ['time'])
std_Aus = mean_mon_Aus.sel(time = slice('1850-01', '1881-01')).std(dim = ['time'])
std_EA = mean_mon_EA.sel(time = slice('1850-01', '1881-01')).std(dim = ['time'])

# %%
# calculate the mean for each model over the time period from 1850-1880
time_mean_Glob = mean_mon_Glob.sel(time = slice('1850-01', '1881-01')).mean(dim = ['time'])
time_mean_SH = mean_mon_SH.sel(time = slice('1850-01', '1881-01')).mean(dim = ['time'])
time_mean_Aus = mean_mon_Aus.sel(time = slice('1850-01', '1881-01')).mean(dim = ['time'])
time_mean_EA = mean_mon_EA.sel(time = slice('1850-01', '1881-01')).mean(dim = ['time'])

# %% [markdown]
# # Count below threshold for each model
# First select only the values below our threshold, then get the count of unmasked values along the time dimension

# %%
func = reload(func)

# %%
# count the number of times the anomalies are below 1std, 2std, 3std in the 6 months post-eruption
std_count_6mon_Glob = std_count(mean_mon_Glob, time_mean_Glob, std_Glob, e_date[0], e_post6mon[0])
std_count_6mon_SH = std_count(mean_mon_SH, time_mean_SH, std_SH, e_date[0], e_post6mon[0])
std_count_6mon_Aus = std_count(mean_mon_Aus, time_mean_Aus, std_Aus, e_date[0], e_post6mon[0])
std_count_6mon_EA = std_count(mean_mon_EA, time_mean_EA, std_EA, e_date[0], e_post6mon[0])

# %%
# count the number of times the anomalies are below 1std, 2std, 3std in the 6-12 months post-eruption
std_count_12mon_Glob = std_count(mean_mon_Glob, time_mean_Glob, std_Glob, e_post6mon[0], e_post12mon[0])
std_count_12mon_SH = std_count(mean_mon_SH, time_mean_SH, std_SH, e_post6mon[0], e_post12mon[0])
std_count_12mon_Aus = std_count(mean_mon_Aus, time_mean_Aus, std_Aus, e_post6mon[0], e_post12mon[0])
std_count_12mon_EA = std_count(mean_mon_EA, time_mean_EA, std_EA, e_post6mon[0], e_post12mon[0])

# %%
# count the number of times the anomalies are below 1std, 2std, 3std in the 12-18 months post-eruption
std_count_18mon_Glob = std_count(mean_mon_Glob, time_mean_Glob, std_Glob, e_post12mon[0], e_post18mon[0])
std_count_18mon_SH = std_count(mean_mon_SH, time_mean_SH, std_SH, e_post12mon[0], e_post18mon[0])
std_count_18mon_Aus = std_count(mean_mon_Aus, time_mean_Aus, std_Aus, e_post12mon[0], e_post18mon[0])
std_count_18mon_EA = std_count(mean_mon_EA, time_mean_EA, std_EA, e_post12mon[0], e_post18mon[0])

# %%
# count the number of times the anomalies are below 1std, 2std, 3std in the 18-24 months post-eruption
std_count_24mon_Glob = std_count(mean_mon_Glob, time_mean_Glob, std_Glob, e_post18mon[0], e_post24mon[0])
std_count_24mon_SH = std_count(mean_mon_SH, time_mean_SH, std_SH, e_post18mon[0], e_post24mon[0])
std_count_24mon_Aus = std_count(mean_mon_Aus, time_mean_Aus, std_Aus, e_post18mon[0], e_post24mon[0])
std_count_24mon_EA = std_count(mean_mon_EA, time_mean_EA, std_EA, e_post18mon[0], e_post24mon[0])

# %%
# count the number of times the anomalies are below 1std, 2std, 3std in the 24-60 months post-eruption
std_count_60mon_Glob = std_count(mean_mon_Glob, time_mean_Glob, std_Glob, e_post24mon[0], e_post5yrs[0])
std_count_60mon_SH = std_count(mean_mon_SH, time_mean_SH, std_SH, e_post24mon[0], e_post5yrs[0])
std_count_60mon_Aus = std_count(mean_mon_Aus, time_mean_Aus, std_Aus, e_post24mon[0], e_post5yrs[0])
std_count_60mon_EA = std_count(mean_mon_EA, time_mean_EA, std_EA, e_post24mon[0], e_post5yrs[0])

# %% [markdown]
# # need t ocheck that my std_check function is working properly

# %%
# count the number of times the anomalies are below 1std, 2std, 3std at 5 different time periods post-eruption 
std_count_Glob = func.std_check(mean_mon_Glob, time_mean_Glob, std_Glob, e_date[0])
std_count_SH = func.std_check(mean_mon_SH, time_mean_SH, std_SH, e_date[0])
std_count_Aus = func.std_check(mean_mon_Aus, time_mean_Aus, std_Aus, e_date[0])
std_count_EA = func.std_check(mean_mon_EA, time_mean_EA, std_EA, e_date[0])

# %%
# define datasets for plotting, ie select out model and vairable so xr can be converted to 1d np array
std = std_Aus.sel(model='Multi-model mean').tas
std2 = 2*std_Aus.sel(model='Multi-model mean').tas
std3 = 3*std_Aus.sel(model='Multi-model mean').tas
mean = time_mean_Aus.sel(model='Multi-model mean').tas
d2 = mean_mon_Aus.sel(time = slice('1883-08', '1888-08')).sel(model='Multi-model mean').tas

# %% [markdown]
# ## below cell takes too long to compile, more than half an hour

# %%
# fig = plt.figure(figsize=(14,8))
# # alpha is the opacity 
# # plt.fill_between(d2.time, d2.where(d2>= std).values, std, interpolate =True, color='crimson', alpha=0.5)
# # plt.fill_between(d2.time, d2.where(d2>= mean).values, mean, interpolate =True, color='crimson', alpha=0.2)
# # plt.fill_between(d2.time, d2.where(d2<= mean).values, mean, interpolate =True, color='royalblue', alpha=0.2)
# plt.fill_between(d2.time, d2.where(d2<= -std).values, -std, interpolate =True, color='royalblue', alpha=0.5)
# # plt.fill_between(d2.time, d2.where(d2<= -std2).values, -std2, interpolate =True, color='royalblue', alpha=0.7)
# # plt.fill_between(d2.time, d2.where(d2<= -std3).values, -std3, interpolate =True, color='royalblue', alpha=0.9)
# anom_dataset.plot(color='k')
# plt.axhline(std, color='k', lw=0.8, ls = ':')
# plt.axhline(mean, color='k', lw=0.8)
# plt.axhline(-std, color='k', lw=0.8, ls = ':')
# plt.axhline(-std2, color='k', lw=0.8, ls = ':')
# plt.axhline(-std3, color='k', lw=0.8, ls = ':')

# %%
fig = plt.figure(figsize=(20,30))
axs = []

cols = 4
rows = 11

with dask.diagnostics.ProgressBar():
    for i, m in enumerate(K_mean_mon_Aus.model):
        # Add a subplot with a projection
        ax = fig.add_subplot(rows, cols, i+1)

        # Select this model's data and plot it
        K_mean_mon_Aus.sel(model=m).tas.plot(ax=ax, color='royalblue')
        # plot a horizontal line indicating 3 standard deviations
        ax.axhline(0, color='k', lw=0.8)
        ax.axhline((-std_Aus).sel(model=m).tas, color='k', lw=0.8, ls = ':')
        ax.axhline((-std_Aus*2).sel(model=m).tas, color='k', lw=0.8, ls = ':')
        ax.axhline((-std_Aus*3).sel(model=m).tas, color='k', lw=0.8, ls = ':')
        
        # remove x and y axes
        ax.set_xlabel(None)
        ax.set_ylabel(None)

#plt.savefig('statsig_graph_tas.png', dpi=300, bbox_inches='tight')
# Out:
# [########################################] | 100% Completed |  1.2s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  3.5s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  3.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  1.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  3.1s
# [########################################] | 100% Completed |  3.0s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  3.8s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  1.0s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  3.0s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  3.1s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  1.6s
# [########################################] | 100% Completed |  3.8s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  1.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.9s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.9s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  1.5s
# [########################################] | 100% Completed |  3.0s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  2.9s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  1.6s
# [########################################] | 100% Completed |  3.4s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  3.0s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.9s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  1.5s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  1.0s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.9s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  3.1s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.4s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.9s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  1.1s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.5s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.9s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.9s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  3.0s
# [########################################] | 100% Completed |  3.3s
# [########################################] | 100% Completed |  2.6s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  3.0s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  2.7s
# [####################################### ] | 99% Completed |  2.4s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-148-cbd8524ffba4> in <module>
#      16         ax.axhline((-std_Aus).sel(model=m).tas, color='k', lw=0.8, ls = ':')
#      17         ax.axhline((-std_Aus*2).sel(model=m).tas, color='k', lw=0.8, ls = ':')
# ---> 18         ax.axhline((-std_Aus*3).sel(model=m).tas, color='k', lw=0.8, ls = ':')
#      19
#      20         # remove x and y axes
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/axes/_axes.py in axhline(self, y, xmin, xmax, **kwargs)
#     840         # non-unitized bounds
#     841         self._process_unit_info(ydata=y, kwargs=kwargs)
# --> 842         yy = self.convert_yunits(y)
#     843         scaley = (yy < ymin) or (yy > ymax)
#     844
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/artist.py in convert_yunits(self, y)
#     185         if ax is None or ax.yaxis is None:
#     186             return y
# --> 187         return ax.yaxis.convert_units(y)
#     188
#     189     @property
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1516
#    1517         if self.converter is None:
# -> 1518             self.converter = munits.registry.get_converter(x)
#    1519
#    1520         if self.converter is None:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/units.py in get_converter(self, x)
#     192     def get_converter(self, x):
#     193         """Get the converter interface instance for *x*, or None."""
# --> 194         if hasattr(x, "values"):
#     195             x = x.values  # Unpack pandas Series and DataFrames.
#     196         if isinstance(x, np.ndarray):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/core/dataarray.py in values(self)
#     567     def values(self) -> np.ndarray:
#     568         """The array's data as a numpy.ndarray"""
# --> 569         return self.variable.values
#     570
#     571     @values.setter
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/core/variable.py in values(self)
#     508     def values(self):
#     509         """The variable's data as a numpy.ndarray"""
# --> 510         return _as_array_or_item(self._data)
#     511
#     512     @values.setter
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/core/variable.py in _as_array_or_item(data)
#     270         data = data.get()
#     271     else:
# --> 272         data = np.asarray(data)
#     273     if data.ndim == 0:
#     274         if data.dtype.kind == "M":
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/core.py in __array__(self, dtype, **kwargs)
#    1374
#    1375     def __array__(self, dtype=None, **kwargs):
# -> 1376         x = self.compute()
#    1377         if dtype and x.dtype != dtype:
#    1378             x = x.astype(dtype)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     165         dask.base.compute
#     166         """
# --> 167         (result,) = compute(self, traverse=False, **kwargs)
#     168         return result
#     169
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     450         postcomputes.append(x.__dask_postcompute__())
#     451
# --> 452     results = schedule(dsk, keys, **kwargs)
#     453     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     454
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74                 pools[thread][num_workers] = pool
#      75
# ---> 76     results = get_async(
#      77         pool.apply_async,
#      78         len(pool._pool),
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     473             # Main loop, wait on tasks to finish, insert new ones
#     474             while state["waiting"] or state["ready"] or state["running"]:
# --> 475                 key, res_info, failed = queue_get(queue)
#     476                 if failed:
#     477                     exc, tb = loads(res_info)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/local.py in queue_get(q)
#     131
#     132     def queue_get(q):
# --> 133         return q.get()
#     134
#     135
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/queue.py in get(self, block, timeout)
#     168             elif timeout is None:
#     169                 while not self._qsize():
# --> 170                     self.not_empty.wait()
#     171             elif timeout < 0:
#     172                 raise ValueError("'timeout' must be a non-negative number")
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## need to figure out how to index the model dimension properly

# %%
rows = 11
cols=4
fig, axes = plt.subplots(rows, cols, sharex=True, sharey=True, figsize=(20,40))

# make subplots for each region
m=0

for r in range(rows):
    for c in range(cols):
        with dask.diagnostics.ProgressBar():
            K_mean_mon_Aus.model[m].tas.plot(ax = axes[r,c], color = 'royalblue')

        # plot a horizontal line indicating 3 standard deviations
        ax.axhline(0, color='k', lw=0.8)
        ax.axhline((-std_Aus).model[m].tas, color='k', lw=0.8, ls = ':')
        ax.axhline((-std_Aus*2).model[m].tas, color='k', lw=0.8, ls = ':')
        ax.axhline((-std_Aus*3).model[m].tas, color='k', lw=0.8, ls = ':')

        # remove x and y axes
        ax.set_xlabel(None)
        ax.set_ylabel(None)

        m=m+1
                
#plt.savefig('statsig_graph_tas.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-aa0733c07eca> in <module>
#       9     for c in range(cols):
#      10         with dask.diagnostics.ProgressBar():
# ---> 11             K_mean_mon_Aus.sel(model=m).tas.plot(ax = axes[r,c], color = 'royalblue')
#      12
#      13         # plot a horizontal line indicating 3 standard deviations
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/core/dataset.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2103         """
#    2104         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2105         pos_indexers, new_indexes = remap_label_indexers(
#    2106             self, indexers=indexers, method=method, tolerance=tolerance
#    2107         )
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/core/coordinates.py in remap_label_indexers(obj, indexers, method, tolerance, **indexers_kwargs)
#     395     }
#     396
# --> 397     pos_indexers, new_indexes = indexing.remap_label_indexers(
#     398         obj, v_indexers, method=method, tolerance=tolerance
#     399     )
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/core/indexing.py in remap_label_indexers(data_obj, indexers, method, tolerance)
#     273             coords_dtype = data_obj.coords[dim].dtype
#     274             label = maybe_cast_to_coords_dtype(label, coords_dtype)
# --> 275             idxr, new_idx = convert_label_indexer(index, label, dim, method, tolerance)
#     276             pos_indexers[dim] = idxr
#     277             if new_idx is not None:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/core/indexing.py in convert_label_indexer(index, label, index_name, method, tolerance)
#     194                 indexer = index.get_loc(label_value)
#     195             else:
# --> 196                 indexer = index.get_loc(label_value, method=method, tolerance=tolerance)
#     197         elif label.dtype.kind == "b":
#     198             indexer = label
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 0

# %% [markdown]
# condition = mean_mon_Glob < time_mean_Glob - std_Glob

# %% [markdown]
# ## Minimum values for each model
# The same idea, this time using 'min' instead of 'count'

# %%
# select out time around krakatoa eruption for graphs and counts, 
K_mean_mon_Glob = mean_mon_Glob.sel(time = slice('1883-08', '1888-08'))
K_mean_mon_SH = mean_mon_SH.sel(time = slice('1883-08', '1888-08'))
K_mean_mon_Aus = mean_mon_Aus.sel(time = slice('1883-08', '1888-08'))
K_mean_mon_EA = mean_mon_EA.sel(time = slice('1883-08', '1888-08'))

# %%
# calculate the minimum anomaly (ie the coolest temperature/driest month in the 5 years after krakatoa)
model_min_Glob = K_mean_mon_Glob.min('time')
model_min_SH = K_mean_mon_SH.min('time')
model_min_Aus = K_mean_mon_Aus.min('time')
model_min_EA = K_mean_mon_EA.min('time')

# %% [markdown]
# ## Date of minimum value for each model¶
# Start off by finding the index of the minimum value - argmin.

# %%
# calculate the date of the minimum value for each model and store in an array for each region
min_date_Glob = func.min_date(K_mean_mon_Glob, model_min_Glob)
min_date_SH = func.min_date(K_mean_mon_SH, model_min_SH)
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)

# %%
min_date_Aus = func.min_date(K_mean_mon_Aus, model_min_Aus)
min_date_EA = func.min_date(K_mean_mon_EA, model_min_EA)
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/reductions.py:908: RuntimeWarning: All-NaN slice encountered
#   vals = func(x, axis=arg_axis, keepdims=True)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
event_stats_tas_Aus = xr.Dataset({
    'std': std_count_Aus.tas,
    'Min': model_min_Aus.tas,
    'Min Date': min_date_Aus.tas,
})

event_stats_tas_Aus
# Out:
# <xarray.Dataset>
# Dimensions:       (count_months: 5, model: 44, std_count: 3)
# Coordinates:
#   * model         (model) object 'ACCESS-CM2' ... 'Multi-model mean'
#   * std_count     (std_count) <U5 '1*std' '2*std' '3*std'
#   * count_months  (count_months) <U9 '0-6 mon' '6-12 mon' ... '24-60 mon'
# Data variables:
#     std           (count_months, std_count, model) int64 dask.array<chunksize=(1, 1, 1), meta=np.ndarray>
#     Min           (model) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#     Min Date      (model) datetime64[ns] 1884-02-29 1886-01-31 ... 1884-03-31

# %%
event_stats_tas_Aus_df = event_stats_tas_Aus.to_dataframe()
event_stats_tas_Aus_df = event_stats_tas_Aus_df.round(decimals=2)
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
event_stats_tas_Aus_df
# Out:
#                                          std   Min   Min Date
# count_months model            std_count
# 0-6 mon      ACCESS-CM2       1*std        1 -2.28 1884-02-29
#                               2*std        1 -2.28 1884-02-29
#                               3*std        0 -2.28 1884-02-29
#              ACCESS-ESM1-5    1*std        1 -1.17 1886-01-31
#                               2*std        0 -1.17 1886-01-31
# ...                                      ...   ...        ...
# 24-60 mon    TaiESM1          2*std        1 -1.92 1887-08-31
#                               3*std        0 -1.92 1887-08-31
#              Multi-model mean 1*std       25 -0.54 1884-03-31
#                               2*std        8 -0.54 1884-03-31
#                               3*std        1 -0.54 1884-03-31
#
# [660 rows x 3 columns]

# %%
result_month = event_stats_tas_Aus_df.pivot_table(index='model', columns=['count_months', 'std_count'])

import seaborn as sns

cm = sns.light_palette("blue", as_cmap=True)

s = result_month.style.background_gradient(cmap=cm)
s

# def background(std):

#     result_month = std > 0
#     return ['background-color: royalblue' if v 
#         else '' for v in result_month]

# result_month.style.apply(background)
# Out:
# <style  type="text/css" >
# #T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col0,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col1,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col2,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col3,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col4,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col5,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col6,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col7,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col8,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col9,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col10,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col11,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col12,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col13,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col14,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col24,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row13_col24,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row20_col24,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row23_col24,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row25_col24{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row5_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row5_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row6_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row8_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row9_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row10_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row12_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row13_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row14_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row14_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row15_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row16_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row17_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row19_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row21_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row21_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row23_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row23_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row25_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row27_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row28_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row29_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row29_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row30_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row30_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row31_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row33_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row33_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row33_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row34_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row34_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row35_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row35_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row39_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row40_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row42_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row42_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row42_col27{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col16,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col16,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row5_col16,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row5_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row6_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row7_col16,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row8_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row11_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row11_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row12_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row13_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row14_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row15_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row16_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row18_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row19_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row20_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row22_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row23_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row24_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row25_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row26_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row29_col16,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row29_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row31_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row32_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row34_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row35_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row36_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row36_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row39_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row41_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row41_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row43_col18{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col17,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col19,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col20,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col22,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col23,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col26,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row0_col29,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col16,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col17,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col19,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col20,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col22,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col23,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col25,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col26,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col27,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row1_col29,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col17,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col19,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col20,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col22,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col23,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col25,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col26,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row2_col29,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col16,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col17,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col20,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col21,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col22,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col23,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col26,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row3_col29,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col15,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col16,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col17,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col18,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col19,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col20,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col21,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col22,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col23,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col26,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col28,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row4_col29,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row5_col17,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row5_col19,#T_eaa8681c_32d1_11eb_ac01_fa163e2667b6row5_col20,#T_eaa8681c_32d1_11eb_ac01_fa163e

# %%
# The text for the combined result
# ('model','std_count','count_months', 'Min', 'Min Date')
result_month = event_stats_tas_Aus_df.pivot_table(index='model', columns=['count_months', 'std_count'])
type_background = {
#     3 : 'background-color: royalblue',
#     2 : 'background-color: dodgerblue',
    0 : 'background-color: lightblue',
}
background = result_month.applymap(lambda x: type_background[x])
table = result_month.style.apply(lambda x: background, axis=None)
table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-3a0644f56825> in <module>
#       7     0 : 'background-color: lightblue',
#       8 }
# ----> 9 background = result_month.applymap(lambda x: type_background[x])
#      10 table = result_month.style.apply(lambda x: background, axis=None)
#      11 table
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/pandas/core/frame.py in applymap(self, func)
#    7607             return lib.map_infer(x.astype(object)._values, func)
#    7608
# -> 7609         return self.apply(infer)
#    7610
#    7611     # ----------------------------------------------------------------------
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7550             kwds=kwds,
#    7551         )
# -> 7552         return op.get_result()
#    7553
#    7554     def applymap(self, func) -> "DataFrame":
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/pandas/core/frame.py in infer(x)
#    7605             if x.empty:
#    7606                 return lib.map_infer(x, func)
# -> 7607             return lib.map_infer(x.astype(object)._values, func)
#    7608
#    7609         return self.apply(infer)
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-105-3a0644f56825> in <lambda>(x)
#       7     0 : 'background-color: lightblue',
#       8 }
# ----> 9 background = result_month.applymap(lambda x: type_background[x])
#      10 table = result_month.style.apply(lambda x: background, axis=None)
#      11 table
#
# KeyError: -2.28

# %%
stats_tas_Glob = func.combine_stats(model_2std_count_Glob.tas, model_3std_count_Glob.tas, model_min_Glob.tas, min_date_Glob.tas)
stats_tas_SH = func.combine_stats(model_2std_count_SH.tas, model_3std_count_SH.tas, model_min_SH.tas, min_date_SH.tas)
stats_tas_Aus = func.combine_stats(model_2std_count_Aus.tas, model_3std_count_Aus.tas, model_min_Aus.tas, min_date_Aus.tas)
stats_tas_EA = func.combine_stats(model_2std_count_EA.tas, model_3std_count_EA.tas, model_min_EA.tas, min_date_EA.tas)

# %%
stats_pr_Glob = func.combine_stats(model_2std_count_Glob.pr, model_3std_count_Glob.pr, model_min_Glob.pr, min_date_Glob.pr)
stats_pr_SH = func.combine_stats(model_2std_count_SH.pr, model_3std_count_SH.pr, model_min_SH.pr, min_date_SH.pr)
stats_pr_Aus = func.combine_stats(model_2std_count_Aus.pr, model_3std_count_Aus.pr, model_min_Aus.pr, min_date_Aus.pr)
stats_pr_EA = func.combine_stats(model_2std_count_EA.pr, model_3std_count_EA.pr, model_min_EA.pr, min_date_EA.pr)

# %%
# combine into one dataset for each region and variable 
event_stats_tas_Aus = xr.Dataset({
    'Count 2*std': model_2std_count_Aus.tas,
    'Count 3*std': model_3std_count_Aus.tas,
    'Min': model_min_Aus.tas,
    'Min Date': min_date_Aus.tas,
})

event_stats_tas_Aus
# Out:
# <xarray.Dataset>
# Dimensions:      (model: 44)
# Coordinates:
#   * model        (model) object 'ACCESS-CM2' ... 'Multi-model mean'
# Data variables:
#     Count 2*std  (model) int64 dask.array<chunksize=(1,), meta=np.ndarray>
#     Count 3*std  (model) int64 dask.array<chunksize=(1,), meta=np.ndarray>
#     Min          (model) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#     Min Date     (model) datetime64[ns] 1884-02-29 1886-01-31 ... 1884-03-31

# %%
event_stats_tas_Aus_df = event_stats_tas_Aus.to_dataframe()
event_stats_tas_Aus_df.round(decimals=2)
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
#                    Count 2*std  Count 3*std   Min   Min Date
# model
# ACCESS-CM2                   3            0 -2.28 1884-02-29
# ACCESS-ESM1-5                0            0 -1.17 1886-01-31
# AWI-CM-1-1-MR                2            1 -1.93 1884-08-31
# AWI-ESM-1-1-LR               5            0 -2.21 1886-03-31
# BCC-CSM2-MR                  1            0 -1.76 1886-06-30
# BCC-ESM1                     2            0 -1.97 1887-01-31
# CAMS-CSM1-0                  8            2 -2.51 1888-02-29
# CAS-ESM2-0                   1            4 -1.78 1883-08-31
# CESM2                        2            0 -1.91 1887-03-31
# CESM2-FV2                    5            1 -1.73 1885-07-31
# CESM2-WACCM                  1            1 -2.29 1887-06-30
# CESM2-WACCM-FV2              1            0 -1.90 1887-09-30
# CMCC-CM2-HR4                 2            1 -1.54 1886-11-30
# CMCC-CM2-SR5                 8            4 -2.19 1885-05-31
# CanESM5                      3            0 -2.32 1884-09-30
# E3SM-1-1                     1            1 -1.43 1885-10-31
# E3SM-1-1-ECA                 3            0 -1.66 1887-09-30
# EC-Earth3                    0            0 -1.47 1888-06-30
# EC-Earth3-AerChem           13            3 -2.65 1884-01-31
# EC-Earth3-Veg-LR             3            0 -1.65 1885-01-31
# FGOALS-f3-L                  3            3 -1.76 1885-03-31
# FGOALS-g3                    0            1 -1.09 1884-11-30
# FIO-ESM-2-0                  5            0 -1.93 1884-01-31
# GFDL-CM4                     4            1 -2.16 1886-12-31
# GFDL-ESM4                    1            3 -2.00 1884-10-31
# GISS-E2-1-G                  1            0 -1.90 1888-02-29
# GISS-E2-1-G-CC               0            2 -1.25 1885-10-31
# GISS-E2-1-H                  0            1 -1.51 1886-10-31
# IITM-ESM                     1            2 -1.25 1885-09-30
# INM-CM4-8                    5            0 -1.46 1884-04-30
# INM-CM5-0                    2            1 -1.30 1888-06-30
# IPSL-CM6A-LR                 1            0 -1.96 1884-04-30
# KACE-1-0-G                   6            1 -1.82 1884-03-31
# MIROC6                       0            0 -0.96 1884-08-31
# MPI-ESM-1-2-HAM              1            0 -2.08 1884-12-31
# MPI-ESM1-2-LR                1            1 -1.89 1886-01-31
# MRI-ESM2-0                   3            1 -1.78 1884-02-29
# NESM3                        8            0 -2.16 1883-10-31
# NorCPM1                      3            1 -1.91 1886-12-31
# NorESM2-LM                   1            1 -1.79 1888-04-30
# NorESM2-MM                   1            1 -1.47 1888-06-30
# SAM0-UNICON                  0            1 -1.23 1886-09-30
# TaiESM1                      1            0 -1.92 1887-08-31
# Multi-model mean            21            6 -0.54 1884-03-31

# %% [markdown]
# ## figure out how to convert datafram to latex table

# %% [markdown]
# ## Climtas event detection
# The climtas library has some functions for event detection - it will find runs where a condition is true for multiple times, then let you run a function to calculate statistics for each event

# %%
K_mean_mon_Glob < K_time_mean_Glob - 2*std_Glob

# %%
import climtas

events = climtas.event.find_events(mean_mon_Glob.pr < time_mean_Glob.pr - std_Glob.pr, min_duration=2)
events
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=601.0), HTML(value='')))

# %%
coords = climtas.event.event_coords(mean_mon_Glob.pr, events)

def stat_func(event_data):
    return {'min': event_data.min().values,
            'min_date': event_data.time[event_data.argmin()].values}
    
minimum = climtas.event.map_events(da, events, stat_func)

coords.join(minimum)
