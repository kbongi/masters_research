# %%
import matplotlib.pyplot as plt, numpy as np, pandas as pd

# %%
#read in a csv file 
historical_pr = pd.read_csv('/home/563/kb6999/training/CMIP6_query.csv')

# %%
historical_pr
# Out:
#     activity_id       source_id         source_type experiment_id  \
# 0          CMIP         TaiESM1       AOGCM AER BGC    historical
# 1          CMIP   AWI-CM-1-1-MR               AOGCM    historical
# 2          CMIP  AWI-ESM-1-1-LR               AOGCM    historical
# 3          CMIP     BCC-CSM2-MR               AOGCM    historical
# 4          CMIP        BCC-ESM1      AER AOGCM CHEM    historical
# ..          ...             ...                 ...           ...
# 104        CMIP       GFDL-ESM4  AOGCM AER CHEM BGC    historical
# 105        CMIP           NESM3               AOGCM    historical
# 106        CMIP     SAM0-UNICON       AOGCM BGC AER    historical
# 107        CMIP           CIESM               AOGCM    historical
# 108        CMIP      MCM-UA-1-0               AOGCM    historical
#
#     sub_experiment_id frequency  r  i  p  f  ... variable_id grid_label  \
# 0                none       mon  1  1  1  1  ...          pr         gn
# ...
